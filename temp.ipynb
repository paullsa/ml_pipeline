# %% [markdown]
# # Test code to recreate the pipeline for learning purposes

# %%
def config_loader(config_path):
    import json
    with open(config_path, "r") as f:
        config = json.load(f)
    return config

config = config_loader(r"C:\Python\ml_pipeline\configs\example_run.json")

def loading_data(data_path):
    df = pd.read_csv(data_path)
    return df

df = loading_data(r"data/raw/iris.csv")

# %%
def data_prep(df, target_col, cols_to_exclude):
    cols_to_drop = [target_col] + cols_to_exclude
    X = df.drop(columns=cols_to_drop)
    y = df[target_col]
    return X, y

X, y = data_prep(df, target_col="X", cols_to_exclude=[])

# %%
def train_test_split(X, y, test_size, random_state):
    from sklearn.model_selection import train_test_split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=random_state)
    return X_train, X_test, y_train, y_test

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=config["data"]["test_size"], random_state=config["data"]["random_state"])

# %%
X_train.shape
# Out:
# (120, 4)

# %%
def train_model():
    from sklearn.ensemble import RandomForestClassifier
    model = RandomForestClassifier(n_estimators=config["model"]["n_estimators"], random_state=config["model"]["random_state"])
    model.fit(X_train, y_train)
    return model

print("Training model " + config["model"]["type"] + "...")
# Out:
# Training model xgboost...
